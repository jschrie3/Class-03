# %% [markdown]
# # Quiz 3-2: Pivot
#
# - This quiz will have you pivot a dataset from [data.cms.gov](https://data.cms.gov/Medicare-Inpatient/Inpatient-Prospective-Payment-System-IPPS-Provider/97k6-zzx3)
#
#     - This data is about the Inpatient Prospective Payment System [IPPS]. It includes hospital-specific charges for more than 2000 US hospitals for the top 100 most frequently billed discharges, paid under Medicare based on a rate per discharge.
#
# - During and/or (necessarily) after you have finished this quiz be sure to commit and push using GitHub Desktop.
#
# - Feel free to look back on the lecture/slides and use search engines for help.

# %% [markdown]
# ## 1. Import packages and data
#
# - Import the pandas and numpy packages.
#
# - Import the IPPS dataset:
#     - https://domlockett.github.io/website/ipps-Doms-SP4.csv
#
# - Name the dataset `ipps`.
#
# - Display the dataset.

# %%
#type your solution below this line:

import numpy as np
import pandas as pd
import io
import requests

url = "https://domlockett.github.io/website/ipps-Doms-SP4.csv"
s = requests.get(url).content
ipps = pd.read_csv(io.StringIO(s.decode('utf-8')))
ipps
# Out:
#                         DRG Definition  Provider Id  \
# 0                 149 - DYSEQUILIBRIUM       110003
# 1                 149 - DYSEQUILIBRIUM       110028
# 2                 149 - DYSEQUILIBRIUM       110029
# 3                 149 - DYSEQUILIBRIUM       110035
# 4                 149 - DYSEQUILIBRIUM       110036
# ...                                ...          ...
# 150300  948 - SIGNS & SYMPTOMS W/O MCC       670041
# 150301  948 - SIGNS & SYMPTOMS W/O MCC       670055
# 150302  948 - SIGNS & SYMPTOMS W/O MCC       670056
# 150303  948 - SIGNS & SYMPTOMS W/O MCC       670060
# 150304  948 - SIGNS & SYMPTOMS W/O MCC       670068
#
#                                           Provider Name  \
# 0                       SATILLA REGIONAL MEDICAL CENTER
# 1                                   UNIVERSITY HOSPITAL
# 2                 NORTHEAST GEORGIA MEDICAL CENTER, INC
# 3                          WELLSTAR KENNESTONE HOSPITAL
# 4                     MEMORIAL HEALTH UNIV MED CEN, INC
# ...                                                 ...
# 150300                  SETON MEDICAL CENTER WILLIAMSON
# 150301                     METHODIST STONE OAK HOSPITAL
# 150302                        SETON MEDICAL CENTER HAYS
# 150303       TEXAS REGIONAL MEDICAL CENTER AT SUNNYVALE
# 150304  TEXAS HEALTH PRESBYTERIAN HOSPITAL FLOWER MOUND
#
#        Provider Street Address Provider City Provider State  Provider Zip  \
# 0           410 DARLING AVENUE      WAYCROSS             GA         31501
# 1              1350 WALTON WAY       AUGUSTA             GA         30901
# 2            743 SPRING STREET   GAINESVILLE             GA         30501
# 3            677 CHURCH STREET      MARIETTA             GA         30060
# 4           4700 WATERS AVENUE      SAVANNAH             GA         31403
# ...                        ...           ...            ...           ...
# 150300       201 SETON PARKWAY    ROUND ROCK             TX         78664
# 150301    1139 E SONTERRA BLVD   SAN ANTONIO             TX         78258
# 150302          6001 KYLE PKWY          KYLE             TX         78640
# 150303  231 SOUTH COLLINS ROAD     SUNNYVALE             TX         75182
# 150304  4400 LONG PRAIRIE ROAD  FLOWER MOUND             TX         75028
#
#        Hospital Referral Region Description  Total Discharges  \
# 0                         FL - Jacksonville                12
# 1                              GA - Augusta                13
# 2                              GA - Atlanta                13
# 3                              GA - Atlanta                54
# 4                             GA - Savannah                28
# ...                                     ...               ...
# 150300                          TX - Austin                23
# 150301                     TX - San Antonio                11
# 150302                          TX - Austin                19
# 150303                          TX - Dallas                11
# 150304                          TX - Dallas                12
#
#         Average Covered Charges  Average Total Payments  \
# 0                      12949.33                 3612.66
# 1                      12278.61                 4064.30
# 2                      21549.46                 3944.00
# 3                      23063.24                 4003.46
# 4                      16128.10                 4538.75
# ...                         ...                     ...
# 150300                 26314.39                 3806.86
# 150301                 21704.72                 4027.36
# 150302                 39121.73                 5704.36
# 150303                 28873.09                 7663.09
# 150304                 15042.00                 3539.75
#
#         Average Medicare Payments
# 0                         2583.00
# 1                         2801.23
# 2                         2829.30
# 3                         2638.46
# 4                         3455.17
# ...                           ...
# 150300                    3071.39
# 150301                    2649.72
# 150302                    4058.36
# 150303                    6848.54
# 150304                    2887.41
#
# [150305 rows x 12 columns]

# %%
type(ipps)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ## 2. Pivot the data.
#
# - Pivot the data so we can see the mean of `Average Total Payments` by the procedure which is the column named `DRG Definition`.
# - Sort the data by the average total payments.
#     - Save this pivot to a new variable named `costs` and sort the data by payments.

# %%
#type your solution below this line:


costs = pd.pivot_table(ipps, index = ['DRG Definition'], values= "Average Total Payments", aggfunc= [np.mean])
costs

#costs.sort_values({'Average Total Payments'})
#costs
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-349-83a11a9b0ad8> in <module>
#       5 costs
#       6
# ----> 7 costs.sort_values({'Average Total Payments'})
#       8 #costs
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/core/frame.py in sort_values(self, by, axis, ascending, inplace, kind, na_position, ignore_index)
#    4925
#    4926             by = by[0]
# -> 4927             k = self._get_label_or_level_values(by, axis=axis)
#    4928
#    4929             if isinstance(ascending, (tuple, list)):
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/core/generic.py in _get_label_or_level_values(self, key, axis)
#    1690             values = self.axes[axis].get_level_values(key)._values
#    1691         else:
# -> 1692             raise KeyError(key)
#    1693
#    1694         # Check for duplicates
#
# KeyError: {'Average Total Payments'}
